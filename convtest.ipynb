# %%
import torch
from torch import nn
import matplotlib.pyplot as plt

# %%
a = torch.linspace(0,10,40817)
a *= 10
plt.plot(a.numpy())
plt.show()
a.shape
# Out:
# torch.Size([40817])

# %%
a = a.view(1,-1)
a.shape
# Out:
# torch.Size([1, 40817])

# %%
f = nn.Conv1d(1,1,4,2,1)

# %%
a = f(a)
a.shape
# Out:
# torch.Size([1, 19])

# %%
plt.plot(a.detach().numpy()[0])
