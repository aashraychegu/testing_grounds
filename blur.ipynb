# %%
from CoRe_Dataloader_From_File_With_Random_From_Tensors import get_new_ttv_dataloaders, get_new_test_train_validation_datasets  
import torch
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
_,_,dl = get_new_ttv_dataloaders(0.1,0.05)
gb = transforms.GaussianBlur(31, sigma=(10, 10))

# %%
data,params = next(iter(dl))

# %%
plt.imshow(data[1].cpu().numpy())

# %%
timg = data[1]
oimg = gb(torch.unsqueeze(timg,0))
plt.imshow(torch.squeeze(oimg).cpu().numpy())
plt.show()
plt.imshow(timg.cpu().numpy())
plt.show()
sub = torch.abs(torch.squeeze(oimg)-timg)
plt.imshow(sub.cpu().numpy())
plt.colorbar()
plt.show()
